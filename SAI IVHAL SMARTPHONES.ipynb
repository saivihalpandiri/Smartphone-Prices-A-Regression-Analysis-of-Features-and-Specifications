# %% [markdown]
# ### IMPORTING PACKAGES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ### READING THE DATASET

# %%
df=pd.read_csv('smartphones.csv')

# %%
df.head(2)
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 0           False      snapdragon        8.0              3.2  ...
# 1           False      snapdragon        8.0              2.2  ...
#
#    refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 0           120                 3                1.0  android
# 1           120                 3                1.0  android
#
#    primary_camera_rear  primary_camera_front  extended_memory_available  \
# 0                 50.0                  16.0                          0
# 1                 64.0                  16.0                          1
#
#    extended_upto  resolution_width resolution_height
# 0            NaN              1440              3216
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            960 non-null    object
#  8   num_cores                  974 non-null    float64
#  9   processor_speed            938 non-null    float64
#  10  battery_capacity           969 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              769 non-null    float64
# ...

# %%
df.describe()
# Out:
#                price      rating   num_cores  processor_speed  \
# count     980.000000  879.000000  974.000000       938.000000
# mean    32520.504082   78.258248    7.772074         2.427217
# std     39531.812669    7.402854    0.836845         0.464090
# min      3499.000000   60.000000    4.000000         1.200000
# 25%     12999.000000   74.000000    8.000000         2.050000
# 50%     19994.500000   80.000000    8.000000         2.300000
# 75%     35491.500000   84.000000    8.000000         2.840000
# max    650000.000000   89.000000    8.000000         3.220000
#
#        battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# count        969.000000               980.000000     769.000000    980.000000
# mean        4817.748194                 0.854082      46.126138      6.560204
# std         1009.540054                 0.353205      34.277870      2.744378
# min         1821.000000                 0.000000      10.000000      1.000000
# ...

# %%
df.columns
# Out:
# Index(['brand_name', 'model', 'price', 'rating', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_brand', 'num_cores', 'processor_speed',
#        'battery_capacity', 'fast_charging_available', 'fast_charging',
#        'ram_capacity', 'internal_memory', 'screen_size', 'refresh_rate',
#        'num_rear_cameras', 'num_front_cameras', 'os', 'primary_camera_rear',
#        'primary_camera_front', 'extended_memory_available', 'extended_upto',
#        'resolution_width', 'resolution_height'],
#       dtype='object')

# %%
df['price'].value_counts()
# Out:
# price
# 14999    21
# 19990    17
# 11999    17
# 19999    16
# 16999    16
#          ..
# 28994     1
# 48900     1
# 8890      1
# 18498     1
# 4787      1
# Name: count, Length: 379, dtype: int64

# %% [markdown]
# ### CHECKING FOR THE NULL VALUES AND FILLING THEM WITH MEAN AND MODE

# %%
df.isna().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                       101
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               20
# num_cores                      6
# processor_speed               42
# battery_capacity              11
# fast_charging_available        0
# fast_charging                211
# ram_capacity                   0
# internal_memory                0
# screen_size                    0
# refresh_rate                   0
# num_rear_cameras               0
# num_front_cameras              4
# os                            14
# primary_camera_rear            0
# primary_camera_front           5
# extended_memory_available      0
# extended_upto                480
# resolution_width               0
# resolution_height              0
# dtype: int64

# %%
df.shape
# Out:
# (980, 26)

# %%
df["rating"].unique()
# Out:
# array([89., 81., 75., 82., 80., 86., 85., 84., 79., nan, 65., 72., 76.,
#        87., 88., 83., 73., 64., 68., 74., 78., 62., 66., 69., 67., 71.,
#        77., 61., 60., 63., 70.])

# %%
df["rating"].value_counts()             #finding mean to fill the null values
# Out:
# rating
# 84.0    60
# 82.0    58
# 83.0    55
# 75.0    53
# 85.0    50
# 80.0    49
# 86.0    47
# 79.0    45
# 77.0    38
# 78.0    36
# 81.0    35
# 89.0    35
# 87.0    33
# 74.0    30
# 76.0    29
# 88.0    26
# 71.0    21
# 72.0    18
# 69.0    18
# 73.0    16
# 66.0    15
# 61.0    15
# 65.0    14
# 70.0    14
# 68.0    13
# 67.0    13
# 60.0    12
# 62.0    11
# 64.0    10
# 63.0    10
# Name: count, dtype: int64

# %%
df["rating"].fillna(df["rating"].mean(),inplace=True)

# %%
df["processor_brand"].value_counts()
# Out:
# processor_brand
# snapdragon    413
# helio         201
# dimensity     177
# exynos         50
# bionic         45
# unisoc         26
# tiger          24
# google          9
# kirin           7
# spreadtrum      4
# sc9863a         2
# fusion          1
# mediatek        1
# Name: count, dtype: int64

# %%
df["processor_brand"].mode()
# Out:
# 0    snapdragon
# Name: processor_brand, dtype: object

# %%
df["processor_brand"].fillna("snapdragon",inplace=True)

# %%
df["num_cores"].value_counts()      #mode to fill the null values
# Out:
# num_cores
# 8.0    899
# 6.0     39
# 4.0     36
# Name: count, dtype: int64

# %%
df["num_cores"].mode()
# Out:
# 0    8.0
# Name: num_cores, dtype: float64

# %%
df["num_cores"].fillna(8.0,inplace=True)

# %%
df["processor_speed"].value_counts()   #mean to fill the null values
# Out:
# processor_speed
# 2.00    146
# 2.20    135
# 2.40    128
# 3.20     94
# 2.30     86
# 3.00     53
# 2.84     36
# 2.05     28
# 2.50     23
# 1.80     23
# 1.60     20
# 2.85     19
# 3.22     18
# 3.10     15
# 2.60     14
# 2.90     13
# 1.30     10
# 1.82     10
# 2.73      9
# 2.80      9
# 3.05      8
# 2.36      8
# 1.40      5
# 2.65      5
# 2.70      5
# 1.50      4
# 2.96      3
# 2.86      3
# 3.13      2
# 2.35      1
# 2.37      1
# 1.99      1
# 1.95      1
# 2.10      1
# 1.20      1
# Name: count, dtype: int64

# %%
df["processor_speed"].fillna(df["processor_speed"].mean(),inplace=True)

# %%
df["battery_capacity"].value_counts()      #mode to fill na
# Out:
# battery_capacity
# 5000.0    487
# 4500.0     97
# 6000.0     60
# 4000.0     42
# 4700.0     27
#          ...
# 4730.0      1
# 3520.0      1
# 4080.0      1
# 5600.0      1
# 8000.0      1
# Name: count, Length: 89, dtype: int64

# %%
df["battery_capacity"].mode()
# Out:
# 0    5000.0
# Name: battery_capacity, dtype: float64

# %%
df["battery_capacity"].fillna(5000.0,inplace=True)

# %%
df["fast_charging"].value_counts()              #mean to fillna
# Out:
# fast_charging
# 33.0     152
# 18.0     128
# 67.0      65
# 25.0      53
# 120.0     46
# 15.0      43
# 80.0      42
# 66.0      37
# 10.0      33
# 30.0      32
# 65.0      30
# 44.0      23
# 45.0      17
# 20.0      10
# 68.0       8
# 100.0      7
# 150.0      7
# 125.0      6
# 22.0       5
# 40.0       5
# 60.0       4
# 55.0       3
# 21.0       2
# 210.0      2
# 50.0       2
# 180.0      1
# 200.0      1
# 240.0      1
# 19.0       1
# 135.0      1
# 165.0      1
# 27.0       1
# Name: count, dtype: int64

# %%
df["fast_charging"].fillna(df["fast_charging"].mean(),inplace=True)

# %%
df["num_front_cameras"].value_counts()      #mode to fill na
# Out:
# num_front_cameras
# 1.0    947
# 2.0     29
# Name: count, dtype: int64

# %%
df["num_front_cameras"].mode()
# Out:
# 0    1.0
# Name: num_front_cameras, dtype: float64

# %%
df["num_front_cameras"].fillna(1.0,inplace=True)

# %%
df["os"].value_counts()            #mode to fillna
# Out:
# os
# android    909
# ios         46
# other       11
# Name: count, dtype: int64

# %%
df["os"].mode()
# Out:
# 0    android
# Name: os, dtype: object

# %%
df["os"].fillna("android",inplace=True)

# %%
df["primary_camera_front"].value_counts()              #mean to fillna
# Out:
# primary_camera_front
# 16.0    307
# 8.0     178
# 32.0    155
# 5.0     119
# 12.0     50
# 13.0     41
# 20.0     37
# 10.0     24
# 50.0     12
# 60.0     10
# 44.0      8
# 40.0      6
# 2.0       5
# 7.0       5
# 24.0      3
# 25.0      3
# 10.8      3
# 48.0      2
# 11.1      2
# 0.3       1
# 2.1       1
# 10.7      1
# 10.1      1
# 12.6      1
# Name: count, dtype: int64

# %%
df["primary_camera_front"].fillna(df["primary_camera_front"].mean(),inplace=True)

# %%
df["extended_upto"].value_counts()         #mode to fillna
# Out:
# extended_upto
# 1024.0    263
# 512.0     116
# 256.0     100
# 128.0       9
# 2048.0      6
# 32.0        3
# 64.0        3
# Name: count, dtype: int64

# %%
df["extended_upto"].mode()
# Out:
# 0    1024.0
# Name: extended_upto, dtype: float64

# %%
df["extended_upto"].fillna("1024",inplace=True)

# %%
df.isna().sum()
# Out:
# brand_name                   0
# model                        0
# price                        0
# rating                       0
# has_5g                       0
# has_nfc                      0
# has_ir_blaster               0
# processor_brand              0
# num_cores                    0
# processor_speed              0
# battery_capacity             0
# fast_charging_available      0
# fast_charging                0
# ram_capacity                 0
# internal_memory              0
# screen_size                  0
# refresh_rate                 0
# num_rear_cameras             0
# num_front_cameras            0
# os                           0
# primary_camera_rear          0
# primary_camera_front         0
# extended_memory_available    0
# extended_upto                0
# resolution_width             0
# resolution_height            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     980 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            980 non-null    object
#  8   num_cores                  980 non-null    float64
#  9   processor_speed            980 non-null    float64
#  10  battery_capacity           980 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              980 non-null    float64
# ...

# %%
df.head(2)
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 0           False      snapdragon        8.0              3.2  ...
# 1           False      snapdragon        8.0              2.2  ...
#
#    refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 0           120                 3                1.0  android
# 1           120                 3                1.0  android
#
#    primary_camera_rear  primary_camera_front  extended_memory_available  \
# 0                 50.0                  16.0                          0
# 1                 64.0                  16.0                          1
#
#    extended_upto  resolution_width resolution_height
# 0           1024              1440              3216
# ...

# %%
df.describe()
# Out:
#                price      rating   num_cores  processor_speed  \
# count     980.000000  980.000000  980.000000       980.000000
# mean    32520.504082   78.258248    7.773469         2.427217
# std     39531.812669    7.010599    0.834466         0.454026
# min      3499.000000   60.000000    4.000000         1.200000
# 25%     12999.000000   75.000000    8.000000         2.050000
# 50%     19994.500000   79.000000    8.000000         2.400000
# 75%     35491.500000   84.000000    8.000000         2.840000
# max    650000.000000   89.000000    8.000000         3.220000
#
#        battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# count        980.000000               980.000000     980.000000    980.000000
# mean        4819.793878                 0.854082      46.126138      6.560204
# std         1004.036245                 0.353205      30.360092      2.744378
# min         1821.000000                 0.000000      10.000000      1.000000
# ...

# %%
df.columns
# Out:
# Index(['brand_name', 'model', 'price', 'rating', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_brand', 'num_cores', 'processor_speed',
#        'battery_capacity', 'fast_charging_available', 'fast_charging',
#        'ram_capacity', 'internal_memory', 'screen_size', 'refresh_rate',
#        'num_rear_cameras', 'num_front_cameras', 'os', 'primary_camera_rear',
#        'primary_camera_front', 'extended_memory_available', 'extended_upto',
#        'resolution_width', 'resolution_height'],
#       dtype='object')

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns
# Out:
# Index(['brand_name', 'model', 'price', 'rating', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_brand', 'num_cores', 'processor_speed',
#        'battery_capacity', 'fast_charging_available', 'fast_charging',
#        'ram_capacity', 'internal_memory', 'screen_size', 'refresh_rate',
#        'num_rear_cameras', 'num_front_cameras', 'os', 'primary_camera_rear',
#        'primary_camera_front', 'extended_memory_available', 'extended_upto',
#        'resolution_width', 'resolution_height'],
#       dtype='object')

# %% [markdown]
# ### USING LABEL ENCODER FOR CONVERTING CATEGORICAL VALUES INTO NUMERICAL VALUES

# %%
df.drop(columns=["brand_name"],inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df["os"]=le.fit_transform(df["os"])
df["processor_brand"]=le.fit_transform(df["processor_brand"])
df["model"]=le.fit_transform(df["model"])

# %%
df.head()
# Out:
#    model  price  rating  has_5g  has_nfc  has_ir_blaster  processor_brand  \
# 0    307  54999    89.0    True     True           False                9
# 1    327  19989    81.0    True    False           False                9
# 2    532  16499    75.0    True    False           False                2
# 3    198  14999    81.0    True    False           False                9
# 4    415  24999    82.0    True    False           False                1
#
#    num_cores  processor_speed  battery_capacity  ...  refresh_rate  \
# 0        8.0              3.2            5000.0  ...           120
# 1        8.0              2.2            5000.0  ...           120
# 2        8.0              2.4            5000.0  ...            90
# 3        8.0              2.2            5000.0  ...           120
# 4        8.0              2.6            5000.0  ...           120
#
#    num_rear_cameras  num_front_cameras  os  primary_camera_rear  \
# ...

# %% [markdown]
# ### REPLACING THE VALUES OF TRUE AND FALSE WITH 1 AND 0

# %%
df.replace({True:1,False:0},inplace=True)

# %%
df.head()
# Out:
#    model  price  rating  has_5g  has_nfc  has_ir_blaster  processor_brand  \
# 0    307  54999    89.0       1        1               0                9
# 1    327  19989    81.0       1        0               0                9
# 2    532  16499    75.0       1        0               0                2
# 3    198  14999    81.0       1        0               0                9
# 4    415  24999    82.0       1        0               0                1
#
#    num_cores  processor_speed  battery_capacity  ...  refresh_rate  \
# 0        8.0              3.2            5000.0  ...           120
# 1        8.0              2.2            5000.0  ...           120
# 2        8.0              2.4            5000.0  ...            90
# 3        8.0              2.2            5000.0  ...           120
# 4        8.0              2.6            5000.0  ...           120
#
#    num_rear_cameras  num_front_cameras  os  primary_camera_rear  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   model                      980 non-null    int32
#  1   price                      980 non-null    int64
#  2   rating                     980 non-null    float64
#  3   has_5g                     980 non-null    int64
#  4   has_nfc                    980 non-null    int64
#  5   has_ir_blaster             980 non-null    int64
#  6   processor_brand            980 non-null    int32
#  7   num_cores                  980 non-null    float64
#  8   processor_speed            980 non-null    float64
#  9   battery_capacity           980 non-null    float64
#  10  fast_charging_available    980 non-null    int64
#  11  fast_charging              980 non-null    float64
#  12  ram_capacity               980 non-null    float64
# ...

# %%
x=df.drop(columns="price")
y=df["price"]

# %%
df["extended_upto"]=(df["extended_upto"].astype(float))

# %% [markdown]
# ### PERFORMING EXPLORATORY DATA ANALYSIS

# %%
df.shape
# Out:
# (980, 25)

# %%
for i in df.columns:
    plt.figure(figsize=(8,3))
    plt.boxplot(df[i],vert=False)
    plt.title(i)

# %%
for i in df.columns:
    plt.figure(figsize=(6,3))
    sns.distplot(df[i])
    plt.title(i)

# %% [markdown]
# ### KBEST

# %%
from sklearn.feature_selection import SelectKBest,f_classif,chi2

# %%
best=SelectKBest(chi2,k="all")

# %%
best.fit(x,y)
# Out:
# SelectKBest(k='all', score_func=<function chi2 at 0x00000210DBECB1A0>)

# %%
scores=best.scores_

# %%
chi2= SelectKBest(chi2,k=10)

# %%
kbest=chi2.fit_transform(x,y)

# %%
x_sel=x.columns[chi2.get_support()]

# %%
x_sel
# Out:
# Index(['model', 'battery_capacity', 'fast_charging', 'internal_memory',
#        'refresh_rate', 'primary_camera_rear', 'primary_camera_front',
#        'extended_upto', 'resolution_width', 'resolution_height'],
#       dtype='object')

# %%
df=df[['price','model', 'processor_brand', 'battery_capacity', 'fast_charging','ram_capacity', 'internal_memory', 
'refresh_rate','primary_camera_rear', 'primary_camera_front', 'extended_upto',
       'resolution_width', 'resolution_height']]

# %%
df
# Out:
#      price  model  processor_brand  battery_capacity  fast_charging  \
# 0    54999    307                9            5000.0     100.000000
# 1    19989    327                9            5000.0      33.000000
# 2    16499    532                2            5000.0      15.000000
# 3    14999    198                9            5000.0      46.126138
# 4    24999    415                1            5000.0      67.000000
# ..     ...    ...              ...               ...            ...
# 975  34990    180                9            5000.0      68.000000
# 976  14990     87                9            5000.0      22.000000
# 977  28990    380                1            5080.0      67.000000
# 978  19990    205                9            5000.0      46.126138
# 979  24990    600                9            5000.0      46.126138
#
#      ram_capacity  internal_memory  refresh_rate  primary_camera_rear  \
# 0            12.0            256.0           120                 50.0
# ...

# %% [markdown]
# ## REGRESSION MODEL

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,BaggingRegressor,AdaBoostRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split,cross_val_score,KFold,StratifiedKFold,ShuffleSplit,LeaveOneOut,GridSearchCV
from sklearn.metrics import r2_score

# %%
x=df.drop(columns=['price'])
y=df['price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=10,test_size=0.2)

# %%
model=[DecisionTreeRegressor(criterion="squared_error",min_samples_split=2,max_features=0.8,max_depth=30)
       ,RandomForestRegressor(n_estimators=80,min_samples_split=2,max_features=0.8,max_depth=30,max_samples=0.6),
       BaggingRegressor(n_estimators=100,max_features=0.8,max_samples=0.6),
       SVR(kernel="linear",gamma=0.01,C=10),
       KNeighborsClassifier(n_neighbors=5)]

# %%
for i in model:
    i.fit(x_train,y_train)
    Pred=i.predict(x_test)
    print(r2_score(y_test,Pred))
# Out:
# 0.7213661387175351
# 0.8259538394146465
# 0.8585402238452013
# 0.5194564696396161
# 0.39111412766076925

# %% [markdown]
# ## GRID SEARCH

# %%
grid_param1={
    "criterion":["squared_error","gini"],
    "min_samples_split":[1,2,3,4,5,6],
    "max_features":[1,0.9,0.83,0.7,0.6],
    "max_depth":[20,30,40,50,60]
}

# %%
grid_param2={
    "n_estimators":[50,70,80,900],
    "min_samples_split":[2,3,4.7,5,6],
    "max_features":[1,0.9,0.8,0.7,0.6],
    "max_depth":[20,30,40,50],
    "max_samples":[1,0.9,0.8,0.7,0.6]
}

# %%
grid_param3={
    "n_estimators":[70,80,90,100],
    "max_features":[1,0.9,0.8,0.7,0.6],
    "max_samples":[1,0.9,0.8,0.7,0.6]
}
grid_param4={
    "kernel":["linear","rbf"],
    "gamma":[0.1,0.01],
    "C":[100,80]
}

# %%
grid_param5={
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

# %%
gscv=GridSearchCV(estimator=DecisionTreeRegressor(criterion="squared_error",min_samples_split=2,max_features=0.8,max_depth=30),param_grid=grid_param1,n_jobs=-1,verbose=2)
gscv.fit(x,y)
gscv.best_params_
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
# {'criterion': 'squared_error',
#  'max_depth': 60,
#  'max_features': 0.7,
#  'min_samples_split': 4}

# %%
gscv=GridSearchCV(estimator=RandomForestRegressor(n_estimators=80,min_samples_split=2,max_features=0.8,max_depth=30,max_samples=0.6),param_grid=grid_param2,n_jobs=-1,verbose=2)
gscv.fit(x,y)
gscv.best_params_
# Out:
# Fitting 5 folds for each of 2000 candidates, totalling 10000 fits
# {'max_depth': 50,
#  'max_features': 1,
#  'max_samples': 0.8,
#  'min_samples_split': 2,
#  'n_estimators': 80}

# %%
gscv=GridSearchCV(estimator=BaggingRegressor(n_estimators=100,max_features=0.8,max_samples=0.6),param_grid=grid_param3,n_jobs=-1,verbose=2)
gscv.fit(x,y)
gscv.best_params_
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# {'max_features': 0.7, 'max_samples': 0.9, 'n_estimators': 90}

# %%
gscv=GridSearchCV(estimator=SVR(kernel="linear",gamma=0.01,C=100),param_grid=grid_param4,n_jobs=-1,verbose=2)
gscv.fit(x,y)
gscv.best_params_
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# {'C': 80, 'gamma': 0.1, 'kernel': 'linear'}

# %%
gscv=GridSearchCV(estimator=KNeighborsClassifier(n_neighbors=5),param_grid=grid_param5)
gscv.fit(x,y)
gscv.best_params_
# Out:
# {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'uniform'}

# %%
model=[DecisionTreeRegressor(criterion="squared_error",min_samples_split=2,max_features=0.8,max_depth=30),
       RandomForestRegressor(n_estimators=80,min_samples_split=2,max_features=0.8,max_depth=30,max_samples=0.6),
       SVR(kernel="linear",gamma=0.01,C=10),
       KNeighborsClassifier(n_neighbors=5)]

# %%
for i in model:
    i.fit(x_train,y_train)
    Pred=i.predict(x_test)
    print(r2_score(y_test,Pred))
# Out:
# 0.5986743947711419
# 0.8534739051970066
# 0.5194564696396161
# 0.39111412766076925

# %% [markdown]
# ## CROSS VALIDATION

# %%
kfold=KFold(n_splits=5)
StrkFold=StratifiedKFold(n_splits=5)
Shufflesplit=ShuffleSplit(n_splits=5,test_size=0.2)
loo=LeaveOneOut()

# %%
for i in model:
    cross_score=cross_val_score(i,x,y,cv=kfold)
    print(np.mean(cross_score))
# Out:
# 0.20986584165454714
# 0.6084699403649486
# 0.3766197608324083
# 0.020408163265306124

# %%
for i in model:
    cross_score=cross_val_score(i,x,y,cv=StrkFold)
    print(np.mean(cross_score))
# Out:
# 0.5245080237182409
# 0.57605038613489
# 0.39228597944116306
# 0.019387755102040816

# %%
for i in model:
    cross_score=cross_val_score(i,x,y,cv=Shufflesplit)
    print(np.mean(cross_score))
# Out:
# -0.5319348884164039
# 0.5684109830495943
# 0.41657531585832624
# 0.016326530612244896

# %% [markdown]
# ## STANDARD SCALER

# %%
from sklearn.preprocessing import LabelEncoder,MinMaxScaler,StandardScaler

# %%
scale= StandardScaler()

# %%
xs_train= scale.fit_transform(x_train)
xs_test=scale.transform(x_test)

# %%
model=BaggingRegressor(n_estimators=100,max_features=0.8,max_samples=0.6)
model.fit(xs_train,y_train)
Pred=model.predict(xs_test)
print(r2_score(y_test,Pred))
# Out:
# 0.8380967148937057

# %% [markdown]
# ## ADABOOST

# %%
model=AdaBoostRegressor(n_estimators=5)

# %%
model.fit(x_train,y_train)
# Out:
# AdaBoostRegressor(n_estimators=5)

# %%
Pred=model.predict(x_test)

# %%
print(r2_score(y_test,Pred))
# Out:
# 0.6085667126640528

# %% [markdown]
# ## MINMAX SCALER

# %%
scaler= MinMaxScaler()

# %%
xs_train= scale.fit_transform(x_train)
xs_test=scale.transform(x_test)

# %%
model=BaggingRegressor(n_estimators=100,max_features=0.8,max_samples=0.6)

# %%
model.fit(xs_train,y_train)
# Out:
# BaggingRegressor(max_features=0.8, max_samples=0.6, n_estimators=100)

# %%
pred=model.predict(xs_test)

# %%
print(r2_score(y_test,Pred))
# Out:
# 0.6085667126640528
